# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.utils import resample

# %% [markdown]
# # Seed

# %%
def seed_everything(seed: int):
    import random, os
    import numpy as np
    import torch
    
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
seed_everything(seed=42)

# %% [markdown]
# # Modeling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.utils import resample
import scipy.stats as stats

# -----------------------------------------------------------------
# 1. Updated data from your new table (Ignoring Specificity & NPV)
#    You can add them if you also want to plot them.
# -----------------------------------------------------------------
data = {
    "Days or Full": [
        "Full data",
        "30-day-truncated-data",
        "60-day-truncated-data",
        "90-day-truncated-data"
    ],
    # Values below come from your table:
    #   Accuracy, Precision (PPV), Recall, F1 Score, ROC AUC
    "Accuracy":  [0.637, 0.668, 0.659, 0.684],
    "Precision": [0.696, 0.691, 0.690, 0.687],
    "Recall":    [0.834, 0.929, 0.911, 0.984],
    "F1 Score":  [0.758, 0.793, 0.785, 0.810],
    "ROC AUC":   [0.613, 0.621, 0.613, 0.608],
}

# Create a DataFrame
df = pd.DataFrame(data)

# -----------------------------------------------------------------
# 2. Map textual "Days or Full" to a numeric code for plotting
#    (so the linear regression sees X as numeric)
# -----------------------------------------------------------------
day_mapping = {
    "Full data": 1,
    "30-day-truncated-data": 2,
    "60-day-truncated-data": 3,
    "90-day-truncated-data": 4
}
df["Days or Full"] = df["Days or Full"].map(day_mapping)

# Sort by numeric code so plots go in order: Full → 30 → 60 → 90
df = df.sort_values(by="Days or Full").reset_index(drop=True)

# -----------------------------------------------------------------
# 3. Set up bootstrapped linear regression
# -----------------------------------------------------------------
X = df["Days or Full"].values.reshape(-1, 1)
metrics_to_plot = ["Accuracy", "Precision", "Recall", "F1 Score", "ROC AUC"]

n_bootstraps = 1000
bootstrap_results = {m: [] for m in metrics_to_plot}
predictions_bootstrap = {m: np.zeros(X.shape[0]) for m in metrics_to_plot}

# For storing fitted values/residuals if needed
all_fitted_values = {m: [] for m in metrics_to_plot}
all_residuals = {m: [] for m in metrics_to_plot}

# -----------------------------------------------------------------
# 4. Perform bootstrapped linear regression for each metric
# -----------------------------------------------------------------
for metric in metrics_to_plot:
    y = df[metric].values

    for _ in range(n_bootstraps):
        # Resample X and y
        X_resampled, y_resampled = resample(X, y, replace=True)
        model = LinearRegression()
        model.fit(X_resampled, y_resampled)

        # Store the slope in bootstrap_results
        bootstrap_results[metric].append(model.coef_[0])

        # Predict on original X
        predictions = model.predict(X)
        predictions_bootstrap[metric] += predictions / n_bootstraps

        # Optionally store fitted values and residuals
        residuals = y - predictions
        all_fitted_values[metric].extend(predictions)
        all_residuals[metric].extend(residuals)

# -----------------------------------------------------------------
# 5. Plot each metric's data + average bootstrap fit
# -----------------------------------------------------------------
plt.figure(figsize=(10, 6))
colors = ["purple", "blue", "cyan", "green", "red"]

for i, metric in enumerate(metrics_to_plot):
    # Plot the original data points for this metric
    plt.plot(
        df["Days or Full"], df[metric], 
        marker='o', color=colors[i], 
        label=f"{metric} Data Points"
    )
    # Plot the average bootstrap fit
    plt.plot(
        df["Days or Full"], predictions_bootstrap[metric], 
        linestyle='dashed', color=colors[i],
        label=f"{metric} Avg. Bootstrap Fit"
    )

plt.xlabel("Days or Full")
plt.ylabel("Metric Values")
plt.title("Average Bootstrapped Linear Regression Fit for Updated Metrics")
plt.xticks([1, 2, 3, 4], ["Full data", "30 days", "60 days", "90 days"])
plt.grid(True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.utils import resample

# ------------------------------------------------------------
# 1) Define your X-values (numeric codes for each truncation)
#    In this example:
#       1 -> "Full data"
#       2 -> "30-day-truncated-data"
#       3 -> "60-day-truncated-data"
#       4 -> "90-day-truncated-data"
# ------------------------------------------------------------
data_truncation_days = np.array([1, 2, 3, 4])

# ------------------------------------------------------------
# 2) Define the metric values for each truncation period
#    from your new table:
# ------------------------------------------------------------
metrics = {
    "Accuracy":              [0.637, 0.668, 0.659, 0.684],
    "Precision (PPV)":       [0.696, 0.691, 0.690, 0.687],
    "Recall (Sensitivity)":  [0.834, 0.929, 0.911, 0.984],
    "F1 Score":              [0.758, 0.793, 0.785, 0.810],
    "ROC AUC":               [0.613, 0.621, 0.613, 0.608],
    # If you want Specificity/NPV, just add them:
    # "Specificity":         [...],
    # "NPV":                 [...],
}

# ------------------------------------------------------------
# 3) Perform bootstrapping
# ------------------------------------------------------------
n_bootstrap_samples = 1000  # Number of bootstrap resamples

# Prepare to store the (intercept, slope) for each bootstrap
bootstrap_results = {metric: [] for metric in metrics.keys()}

for metric, values in metrics.items():
    y = np.array(values)
    for _ in range(n_bootstrap_samples):
        # Resample X and y with replacement
        X_resampled, y_resampled = resample(data_truncation_days, y)
        X_resampled = X_resampled.reshape(-1, 1)

        # Fit linear regression
        model = LinearRegression().fit(X_resampled, y_resampled)

        # Store intercept & slope from this bootstrap
        bootstrap_results[metric].append((model.intercept_, model.coef_[0]))

# ------------------------------------------------------------
# 4) Calculate 95% confidence intervals (2.5th, 97.5th percentile)
# ------------------------------------------------------------
bootstrap_conf_intervals = {}
for metric, coeffs in bootstrap_results.items():
    coeffs = np.array(coeffs)  # shape: (n_bootstrap, 2)
    intercepts = coeffs[:, 0]
    slopes = coeffs[:, 1]

    intercept_ci = np.percentile(intercepts, [2.5, 97.5])
    slope_ci = np.percentile(slopes, [2.5, 97.5])

    bootstrap_conf_intervals[metric] = {
        "Intercept CI Lower":      intercept_ci[0],
        "Intercept CI Upper":      intercept_ci[1],
        "Coefficient CI Lower":    slope_ci[0],
        "Coefficient CI Upper":    slope_ci[1]
    }

# Convert the CI dictionary to a DataFrame and display
bootstrap_ci_results = pd.DataFrame(bootstrap_conf_intervals).T
print("95% CI for each metric (intercept & slope):")
print(bootstrap_ci_results)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# ------------------------------------------------------------------
# 1. Example data
# ------------------------------------------------------------------
data = {
    'Dataset': [
        'Full data', 'Full data', 'Full data',
        '30-day-truncated-data', '30-day-truncated-data', '30-day-truncated-data',
        '60-day-truncated-data', '60-day-truncated-data', '60-day-truncated-data',
        '90-day-truncated-data', '90-day-truncated-data', '90-day-truncated-data'
    ],
    'Risk Category': [
        'Low Risk', 'Medium Risk', 'High Risk',
        'Low Risk', 'Medium Risk', 'High Risk',
        'Low Risk', 'Medium Risk', 'High Risk',
        'Low Risk', 'Medium Risk', 'High Risk'
    ],
    'Difference': [
        0.463, 0.177, -0.015,
        0.322, 0.106, 0.009,
        0.344, 0.141, -0.006,
        0.408, 0.135, -0.018
    ]
}
df = pd.DataFrame(data)

# ------------------------------------------------------------------
# 2. Map the "Dataset" to a shorter X-axis label
# ------------------------------------------------------------------
label_map = {
    'Full data': 'Full data',
    '30-day-truncated-data': '30 days',
    '60-day-truncated-data': '60 days',
    '90-day-truncated-data': '90 days'
}
df['Truncation Period'] = df['Dataset'].map(label_map)

# We also want the x-axis in a specific order:
order = ['Full data', '30 days', '60 days', '90 days']

# ------------------------------------------------------------------
# 3. Pivot the data so each Risk Category becomes a column
#    with rows = [Full data, 30 days, 60 days, 90 days]
# ------------------------------------------------------------------
plot_df = df.pivot(
    index='Truncation Period',
    columns='Risk Category',
    values='Difference'
).reindex(order)

# ------------------------------------------------------------------
# 4. Plot each Risk Category line
# ------------------------------------------------------------------
plt.figure(figsize=(8, 5))

plt.plot(plot_df.index, plot_df['Low Risk'],    marker='o', color='orange',  label='Low Risk')
plt.plot(plot_df.index, plot_df['Medium Risk'], marker='o', color='red',     label='Medium Risk')
plt.plot(plot_df.index, plot_df['High Risk'],   marker='o', color='magenta', label='High Risk')

plt.title("Difference between True and Predicted Means across Truncation Periods and Risk Categories")
plt.xlabel("Truncation Period (Days)")
plt.ylabel("True Mean - Predicted Mean")

plt.legend(title="Risk Category")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Recreate your final comparison DataFrame
data = {
    'Dataset': [
        '30_day_data_f1', '30_day_data_f1', '30_day_data_f1',
        '60_day_data_f1', '60_day_data_f1', '60_day_data_f1',
        '90_day_data_f1', '90_day_data_f1', '90_day_data_f1',
        'full_data_f1',  'full_data_f1',   'full_data_f1'
    ],
    'Risk Category': [
        'Low Risk', 'Medium Risk', 'High Risk',
        'Low Risk', 'Medium Risk', 'High Risk',
        'Low Risk', 'Medium Risk', 'High Risk',
        'Low Risk', 'Medium Risk', 'High Risk'
    ],
    'True Mean': [
        0.600000, 0.618806, 0.760933,
        0.529412, 0.624544, 0.764977,
        0.588235, 0.609238, 0.771014,
        0.556604, 0.646221, 0.779141
    ],
    'Predicted Mean': [
        0.242173, 0.500393, 0.758380,
        0.248107, 0.497357, 0.754559,
        0.254783, 0.537688, 0.724154,
        0.219459, 0.457873, 0.721976
    ]
}

df = pd.DataFrame(data)

# Map your dataset names to the desired "truncated"/"full data" labels
mapping = {
    '30_day_data_f1': '30-day-truncated-data',
    '60_day_data_f1': '60-day-truncated-data',
    '90_day_data_f1': '90-day-truncated-data',
    'full_data_f1':    'Full data'
}
df['Dataset'] = df['Dataset'].map(mapping)

# Calculate the difference = True Mean - Predicted Mean
df['Difference'] = df['True Mean'] - df['Predicted Mean']

# Round to three decimals for a neat display
df[['True Mean', 'Predicted Mean', 'Difference']] = df[['True Mean', 'Predicted Mean', 'Difference']].round(3)

print(df)
